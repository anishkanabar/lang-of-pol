# %% [markdown]
# # __DEEPSPEECH @2 TEST__

# %%
import IPython.display as ipd
import deepasr as asr
import tensorflow as tf
import numpy as np
import pandas as pd
import warnings
from asr_dataset.radio import RadioDataset
warnings.filterwarnings('ignore')
# Out:
# 2022-01-09 17:29:01.076495: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# #### __LOAD MODEL__

# %%
# Job 3007629 ran for 500 epochs on 16384 samples. But the loss stayed at inf and it only predicts ' '
model = asr.pipeline.load('/project/graziul/ra/echandler/job_3011512/final_checkpoint')
# Out:
# 2022-01-09 17:29:09.245991: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-01-09 17:29:09.246291: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /software/python-anaconda-2021.05-el8-x86_64/lib:/software/slurm-current-el8-x86_64/lib:/opt/thinlinc/lib64:/opt/thinlinc/lib
# 2022-01-09 17:29:09.246307: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-09 17:29:09.246325: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (midway3-login1.rcc.local): /proc/driver/nvidia/version does not exist
# ...

# %% [markdown]
# #### __PREDICTION EXAMPLE__

# %%
# load transcript data
num_train = 512 # Number of samples used to train loaded model
num_pred = 20 # number of new samples to predict/transcribe
# load transcript data
dataset_loader = RadioDataset('rcc',nrow=num_train+num_pred)
dataset = dataset_loader.data.tail(num_pred)

# %%
# randomly select one utterance as the example
sample = dataset.sample(1)
test_file = sample['path'].values[0]
test_transcript = sample['transcripts'].values[0]

# %%
test_prediction = model.predict(test_file)
# Out:
# 2022-01-09 17:29:27.652612: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-01-09 17:29:27.665427: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3000000000 Hz

# %%
test_transcript
# Out:
# 'COMPUTER INTERACTION ELSA AND FOSTER '

# %%
test_prediction
# Out:
# ['ahvthoe rover']

# %%
ipd.Audio(test_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-flac;base64,..." type="audio/x-flac" />
#                     Your browser does not support the audio element.
#                 </audio>
