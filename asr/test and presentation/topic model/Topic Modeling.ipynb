# %% [markdown]
# # Topic Modeling

# %% [markdown]
# > Interpretation

# %%
# !git clone https://github.com/UrbanResiliencyInitiative/lang-of-pol.git lang-of-pol-repo
# !pip install wordcloud
# !conda install gensim

# %%
import numpy as np
import pandas as pd
import nltk
import re
from wordcloud import WordCloud, ImageColorGenerator
import gensim
import pyLDAvis
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/shiyang/opt/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
numwords = ['ONE', 'TWO', 'THREE', 'FOUR', 'FIVE', \
                 'SIX', 'SEVEN', 'EIGHT', 'NINE', 'TEN', \
                 'ELEVEN', 'TWELVE', 'THIRTEEN', 'FOURTEEN', \
                 'FIFTEEN', 'SIXTEEN', 'SEVENTEEN', 'EIGHTEEN', \
                 'NINETEEN', 'TWENTY', 'THIRTY', 'FORTY', \
                 'FIFTY', 'SIXTY', 'SEVENTY', 'EIGHTY', \
                 'NINETY', 'ZERO']

stopword_list = ['ON', 'THE', 'A', 'AND', 'UH', 'IN', 'TO', 'AT', 'THAT', 'FOR', 'IS', 'WITH', 'OF', 'OH', 'ARE',
                 'THIS', 'IF', 'S', 'I', 'IT']

indicators = ['GUN']

# %%
text = pd.read_csv('transcript_files.csv', usecols=['offset', 'duration', 'transcripts'])

# %%
def combination(by: list, string: str):
    """
    return a list of number combination
    """
    words = string.split(' ')
    comb_list = []
    comb = []
    for i in range(len(words)):
        if words[i] in by:
            comb.append(words[i])
            comb_list.append(tuple(comb.copy()))
        elif words[i] not in by:
            comb = []
    return comb_list

# %%
comb_dict = {}
for index, row in text.iterrows():
    _ = combination(indicators, row['transcripts'])
    for comb in _:
        if comb in comb_dict.keys():
            comb_dict[comb].append(row['transcripts'])
        else:
            comb_dict[comb] = [row['transcripts']]

# %%
comb_dict
# Out:
# {('GUN',): ['SIMULCAST IS NOT AVAILABLE FOR A PERSON WITH A GUN THIRTY NINE EIGHTEEN WEST MONTROSE, THREE NINE ONE EIGHT WEST MONTROSE',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   'YOU WANNA START RIDING ON THAT SHE SAID SHE SAID CLEVELAND CALLED FIRST SAYING FEMALE NEEDS TO GO SHE’S HIGH AND THE FEMALE CALLED MS. WIGGINS SAYING THAT HER EX-BOYFRIEND CHOKED HER AND HAS A BB GUN THIRTY FOUR O SEVEN SUNNYSIDE THREE FOUR O SEVEN ON SUNNYSIDE',
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT'S GIVING A SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN",
#   "UNITS IN SEVENTEEN UNDER CITYWIDE IS GETTING A SLOW DOWN FOR THE PERSON WITH THE GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT'S ON SCENE GIVE THAT SLOW DOWN NOTHING FURTHER SEVENTEEN DISTRICT ZONE ONE CLEAR",
#   'MR. DOAS SAYS HE WAS SITTING IN HIS CAR AND WAS ROBBED AT GUN POINT MALE BLACK WITH A BLACK HOODIE',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR A PERSON WITH A GUN',
#   'UNITS IN SEVENTEEN ON THE CITY WIDE GETTING A SLOW DOWN FOR A PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT ASKING YOU TO SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT ON ONE CLEAR',
#   "FOR THE UNITS IN SIXTEEN AND ON THE CITY WIDE WE'RE GONNA TICKET A PERSON WITH A GUN AT GAYLE AND MILWAUKEE",
#   'CALLER SAYS HER SON SIXTEEN YEARS OF AGE WAS ROBBED AT GUN POINT AT THE SUPER MARKET BY TWO MALE HISPANICS ONE JACKET',
#   'THINKS IT WAS FIREWORKS OR GUN FIRE',
#   " OKAY WE'VE GOT A GUN RECOVERED OVER HERE",
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE',
#   "UH CHRISSY SAID SHE HEARD ONE SINGLE GUN SHOT IN THE AREA SO FAR IT'S THE ONLY CALL",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "HE GOT A CALL FROM ANOTHER EMPLOYEE THAT HE'S THAT HE'S LOOKING FOR A GUN AND IS PLANNING TO RETURN TO THE STORE",
#   "FORTY UNITS AT SIXTEEN IN ON A CITYWIDE WE'RE GONNA TAKE IT OVER PERSON WITH A GUN AT GALE AND MILWAUKEE IT'S A MCDONALD'S PARKING LOT TWO TO THREE MALE HISPANICS ARE INSIDE AND THERE'S A BLUE HONDA CRV",
#   'FOUR NINE ZERO ZERO BLOCK WEST PATTERSON AVENUE THREE GUN SHOTS HEARD ON THE CORNER BETWEEN PATTERSON AND LEMONT NOTHING FURTHER THAN ONE STATION CLEAR ',
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE ',
#   " YEAH WE'RE STILL OUTSIDE OF THE BUILDING WAITING FOR THE LADY TO TURN IN THE GUN",
#   ' DO YOU WANNA DO THIS GUN TURN IN',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   "YEAH WE'RE STILL IN FRONT OF THE BUILDING WAITING FOR A LADY TO TURN IN THE GUN",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   'SO YOU WANNA DO THIS GUN TURN IN',
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT YOU'LL HAVE TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN ",
#   'ELEVEN ROBERT TEN FOUR AGAIN SOME PERSON WITH A GUN',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND GOT A PERSON WITH A GUN',
#   'UNITS SEVENTEEN ON THE CITY WIDE SLOW DOWN FOR THE PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT IS LISTENING SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT IS ON ALL CLEAR',
#   ' UNITS AND EIGHTEEN ON THE CITYWIDE WE HAVE A CALL OF A PERSON WITH A GUN <AS PARK> TWENTY TWENTY ONE <EARTH> ',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION UH",
#   " GARY AND WINSTON IS THE OFFENDER PULLED A GUN ON HER AND THAT'S HER BOYFRIEND ALL THE INFO COMING IN",
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS AND HEADING SOUTHBOUND NOTHING FURTHER',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION",
#   ' YEAH ITS UH MALE WITH A GUN CALL OVER ON UH LA SALLE AND HUBBARD UHM',
#   'THE OFFENDER PULLED A GUN ON HER AND',
#   ' ALL UNITS IN TWO AND CITY WIDE IN TWO TWENTY FIVE WE HAVE A PERSON WITH A GUN. FIVE ONE ONE ZERO SOUTH CALUMET. FIVE ONE ONE ZERO SOUTH CALUMET. PER THE ANNONYMOUS CALLER ONE MALE BLACK BLUE JEANS SHIRT BLUE JEANS PASSED THE GUN TO SECOND MALE BLACK WEARING A WHITE TANK TOP AND GREY SHORTS BOTH STANDING OUTSIDE IN FRONT. THIS IS ZONE FIVE RADIO STATION',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE <NEIGHBOR>',
#   ' WITH A GUN ROBBED THE STORE',
#   " HE'S GOT A TANK TOP GRAY JEANS GUN IN HIS WAIST AND A WHEEL CHAIR",
#   " WELL HE WAS SAYING SOMEBODY WAS ARMED WITH A GUN AND I CAN'T WE IF IT WAS A BONA FIDE ARMED ROBBERY WE'D HAVE TO DO PAPER IN THE FIELD",
#   " YEAH JUST CAUSE YOU'RE GOING TO THE AREA UM UNITS IN SIX JUST A HEADS UP PERSON WITH A GUN SEVEN FIVE AND PEORIA",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " SOMEONE'S IN A RED FOUR-DOOR SUV PASADENA ACURA SHOT HER IN THE LEG WITH A PAINTBALL GUN ",
#   ' RED VEHICLE WITH THE PAINT GUN',
#   " ALRIGHT AND ALSO HE'S A CONVICTED GUN OFFENDER",
#   ' UH THE GANG LEFT AND CAME BACK AND SOMEONE SAYS ONE OF THEM HAS A GUN',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   'SIMULCAST IS NOT AVAILABLE FOR A PERSON WITH A GUN THIRTY NINE EIGHTEEN WEST MONTROSE, THREE NINE ONE EIGHT WEST MONTROSE',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   'YOU WANNA START RIDING ON THAT SHE SAID SHE SAID CLEVELAND CALLED FIRST SAYING FEMALE NEEDS TO GO SHE’S HIGH AND THE FEMALE CALLED MS. WIGGINS SAYING THAT HER EX-BOYFRIEND CHOKED HER AND HAS A BB GUN THIRTY FOUR O SEVEN SUNNYSIDE THREE FOUR O SEVEN ON SUNNYSIDE',
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT'S GIVING A SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN",
#   "UNITS IN SEVENTEEN UNDER CITYWIDE IS GETTING A SLOW DOWN FOR THE PERSON WITH THE GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT'S ON SCENE GIVE THAT SLOW DOWN NOTHING FURTHER SEVENTEEN DISTRICT ZONE ONE CLEAR",
#   'MR. DOAS SAYS HE WAS SITTING IN HIS CAR AND WAS ROBBED AT GUN POINT MALE BLACK WITH A BLACK HOODIE',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR A PERSON WITH A GUN',
#   'UNITS IN SEVENTEEN ON THE CITY WIDE GETTING A SLOW DOWN FOR A PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT ASKING YOU TO SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT ON ONE CLEAR',
#   "FOR THE UNITS IN SIXTEEN AND ON THE CITY WIDE WE'RE GONNA TICKET A PERSON WITH A GUN AT GAYLE AND MILWAUKEE",
#   'CALLER SAYS HER SON SIXTEEN YEARS OF AGE WAS ROBBED AT GUN POINT AT THE SUPER MARKET BY TWO MALE HISPANICS ONE JACKET',
#   'THINKS IT WAS FIREWORKS OR GUN FIRE',
#   " OKAY WE'VE GOT A GUN RECOVERED OVER HERE",
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE',
#   "UH CHRISSY SAID SHE HEARD ONE SINGLE GUN SHOT IN THE AREA SO FAR IT'S THE ONLY CALL",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "HE GOT A CALL FROM ANOTHER EMPLOYEE THAT HE'S THAT HE'S LOOKING FOR A GUN AND IS PLANNING TO RETURN TO THE STORE",
#   "FORTY UNITS AT SIXTEEN IN ON A CITYWIDE WE'RE GONNA TAKE IT OVER PERSON WITH A GUN AT GALE AND MILWAUKEE IT'S A MCDONALD'S PARKING LOT TWO TO THREE MALE HISPANICS ARE INSIDE AND THERE'S A BLUE HONDA CRV",
#   'FOUR NINE ZERO ZERO BLOCK WEST PATTERSON AVENUE THREE GUN SHOTS HEARD ON THE CORNER BETWEEN PATTERSON AND LEMONT NOTHING FURTHER THAN ONE STATION CLEAR ',
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE ',
#   " YEAH WE'RE STILL OUTSIDE OF THE BUILDING WAITING FOR THE LADY TO TURN IN THE GUN",
#   ' DO YOU WANNA DO THIS GUN TURN IN',
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MONTROSE THREE TWO ZERO ONE MONTROSE AT THE BP STATION. RODRIGO MENDOZA SAYS THERE WAS A GUY WITH A GUN AND A BLACK CAR THAT'S FOLLOWING HIM. HE'S STILL IN THE AREA, CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MONTROSE THREE TWO ZERO ONE MONTROSE AT THE BP STATION. RODRIGO MENDOZA SAYS THERE WAS A GUY WITH A GUN AND A BLACK CAR THAT'S FOLLOWING HIM. HE'S STILL IN THE AREA, CALLER'S WAITING INSIDE THE GAS STATION",
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   "YEAH WE'RE STILL IN FRONT OF THE BUILDING WAITING FOR A LADY TO TURN IN THE GUN",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   'SO YOU WANNA DO THIS GUN TURN IN',
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT YOU'LL HAVE TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN ",
#   'ELEVEN ROBERT TEN FOUR AGAIN SOME PERSON WITH A GUN',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND GOT A PERSON WITH A GUN',
#   'UNITS SEVENTEEN ON THE CITY WIDE SLOW DOWN FOR THE PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT IS LISTENING SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT IS ON ALL CLEAR',
#   ' UNITS AND EIGHTEEN ON THE CITYWIDE WE HAVE A CALL OF A PERSON WITH A GUN <AS PARK> TWENTY TWENTY ONE <EARTH> ',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION UH",
#   " GARY AND WINSTON IS THE OFFENDER PULLED A GUN ON HER AND THAT'S HER BOYFRIEND ALL THE INFO COMING IN",
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS AND HEADING SOUTHBOUND NOTHING FURTHER',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION",
#   ' YEAH ITS UH MALE WITH A GUN CALL OVER ON UH LA SALLE AND HUBBARD UHM',
#   'THE OFFENDER PULLED A GUN ON HER AND',
#   ' ALL UNITS IN TWO AND CITY WIDE IN TWO TWENTY FIVE WE HAVE A PERSON WITH A GUN. FIVE ONE ONE ZERO SOUTH CALUMET. FIVE ONE ONE ZERO SOUTH CALUMET. PER THE ANNONYMOUS CALLER ONE MALE BLACK BLUE JEANS SHIRT BLUE JEANS PASSED THE GUN TO SECOND MALE BLACK WEARING A WHITE TANK TOP AND GREY SHORTS BOTH STANDING OUTSIDE IN FRONT. THIS IS ZONE FIVE RADIO STATION',
#   ' DRIVER WAVED A GUN AT HIM WITH THREE UH THREE HISPANICS INSIDE THE CAR WITH HIM SAYS THEY WERE RIDING SLOWLY IN A BLUE PICKUP TRUCK LOCAL RED TYSON LAST SEEN GOING NORTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE',
#   'PERSON WITH A GUN TWENTY NINE SEVENTY ONE SOUTH STATE TWO NINE SEVEN ONE SOUTH ',
#   'TWO THREE HENRY IF YOU COULD START RIDING IN AT TWO NINE SEVEN ONE SOUTH STATE PERSON WITH A GUN PERSON JUST BROKE INTO THE BUILDING SECURITY TOLD ME',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE <NEIGHBOR>',
#   ' WITH A GUN ROBBED THE STORE',
#   " HE'S GOT A TANK TOP GRAY JEANS GUN IN HIS WAIST AND A WHEEL CHAIR",
#   " WELL HE WAS SAYING SOMEBODY WAS ARMED WITH A GUN AND I CAN'T WE IF IT WAS A BONA FIDE ARMED ROBBERY WE'D HAVE TO DO PAPER IN THE FIELD",
#   " YEAH JUST CAUSE YOU'RE GOING TO THE AREA UM UNITS IN SIX JUST A HEADS UP PERSON WITH A GUN SEVEN FIVE AND PEORIA",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " SOMEONE'S IN A RED FOUR-DOOR SUV PASADENA ACURA SHOT HER IN THE LEG WITH A PAINTBALL GUN ",
#   ' RED VEHICLE WITH THE PAINT GUN',
#   " ALRIGHT AND ALSO HE'S A CONVICTED GUN OFFENDER",
#   ' UH THE GANG LEFT AND CAME BACK AND SOMEONE SAYS ONE OF THEM HAS A GUN',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   'SIMULCAST IS NOT AVAILABLE FOR A PERSON WITH A GUN THIRTY NINE EIGHTEEN WEST MONTROSE, THREE NINE ONE EIGHT WEST MONTROSE',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   'YOU WANNA START RIDING ON THAT SHE SAID SHE SAID CLEVELAND CALLED FIRST SAYING FEMALE NEEDS TO GO SHE’S HIGH AND THE FEMALE CALLED MS. WIGGINS SAYING THAT HER EX-BOYFRIEND CHOKED HER AND HAS A BB GUN THIRTY FOUR O SEVEN SUNNYSIDE THREE FOUR O SEVEN ON SUNNYSIDE',
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT'S GIVING A SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN",
#   "UNITS IN SEVENTEEN UNDER CITYWIDE IS GETTING A SLOW DOWN FOR THE PERSON WITH THE GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT'S ON SCENE GIVE THAT SLOW DOWN NOTHING FURTHER SEVENTEEN DISTRICT ZONE ONE CLEAR",
#   'MR. DOAS SAYS HE WAS SITTING IN HIS CAR AND WAS ROBBED AT GUN POINT MALE BLACK WITH A BLACK HOODIE',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR A PERSON WITH A GUN',
#   'UNITS IN SEVENTEEN ON THE CITY WIDE GETTING A SLOW DOWN FOR A PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT ASKING YOU TO SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT ON ONE CLEAR',
#   "FOR THE UNITS IN SIXTEEN AND ON THE CITY WIDE WE'RE GONNA TICKET A PERSON WITH A GUN AT GAYLE AND MILWAUKEE",
#   'CALLER SAYS HER SON SIXTEEN YEARS OF AGE WAS ROBBED AT GUN POINT AT THE SUPER MARKET BY TWO MALE HISPANICS ONE JACKET',
#   'THINKS IT WAS FIREWORKS OR GUN FIRE',
#   " OKAY WE'VE GOT A GUN RECOVERED OVER HERE",
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE',
#   "UH CHRISSY SAID SHE HEARD ONE SINGLE GUN SHOT IN THE AREA SO FAR IT'S THE ONLY CALL",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "HE GOT A CALL FROM ANOTHER EMPLOYEE THAT HE'S THAT HE'S LOOKING FOR A GUN AND IS PLANNING TO RETURN TO THE STORE",
#   "FORTY UNITS AT SIXTEEN IN ON A CITYWIDE WE'RE GONNA TAKE IT OVER PERSON WITH A GUN AT GALE AND MILWAUKEE IT'S A MCDONALD'S PARKING LOT TWO TO THREE MALE HISPANICS ARE INSIDE AND THERE'S A BLUE HONDA CRV",
#   'FOUR NINE ZERO ZERO BLOCK WEST PATTERSON AVENUE THREE GUN SHOTS HEARD ON THE CORNER BETWEEN PATTERSON AND LEMONT NOTHING FURTHER THAN ONE STATION CLEAR ',
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE ',
#   " YEAH WE'RE STILL OUTSIDE OF THE BUILDING WAITING FOR THE LADY TO TURN IN THE GUN",
#   ' DO YOU WANNA DO THIS GUN TURN IN',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   "YEAH WE'RE STILL IN FRONT OF THE BUILDING WAITING FOR A LADY TO TURN IN THE GUN",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   'SO YOU WANNA DO THIS GUN TURN IN',
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT YOU'LL HAVE TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN ",
#   'ELEVEN ROBERT TEN FOUR AGAIN SOME PERSON WITH A GUN',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND GOT A PERSON WITH A GUN',
#   'UNITS SEVENTEEN ON THE CITY WIDE SLOW DOWN FOR THE PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT IS LISTENING SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT IS ON ALL CLEAR',
#   ' UNITS AND EIGHTEEN ON THE CITYWIDE WE HAVE A CALL OF A PERSON WITH A GUN <AS PARK> TWENTY TWENTY ONE <EARTH> ',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION UH",
#   " GARY AND WINSTON IS THE OFFENDER PULLED A GUN ON HER AND THAT'S HER BOYFRIEND ALL THE INFO COMING IN",
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS AND HEADING SOUTHBOUND NOTHING FURTHER',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION",
#   ' YEAH ITS UH MALE WITH A GUN CALL OVER ON UH LA SALLE AND HUBBARD UHM',
#   'THE OFFENDER PULLED A GUN ON HER AND',
#   ' ALL UNITS IN TWO AND CITY WIDE IN TWO TWENTY FIVE WE HAVE A PERSON WITH A GUN. FIVE ONE ONE ZERO SOUTH CALUMET. FIVE ONE ONE ZERO SOUTH CALUMET. PER THE ANNONYMOUS CALLER ONE MALE BLACK BLUE JEANS SHIRT BLUE JEANS PASSED THE GUN TO SECOND MALE BLACK WEARING A WHITE TANK TOP AND GREY SHORTS BOTH STANDING OUTSIDE IN FRONT. THIS IS ZONE FIVE RADIO STATION',
#   ' DRIVER WAVED A GUN AT HIM WITH THREE UH THREE HISPANICS INSIDE THE CAR WITH HIM SAYS THEY WERE RIDING SLOWLY IN A BLUE PICKUP TRUCK LOCAL RED TYSON LAST SEEN GOING NORTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE',
#   'PERSON WITH A GUN TWENTY NINE SEVENTY ONE SOUTH STATE TWO NINE SEVEN ONE SOUTH ',
#   'TWO THREE HENRY IF YOU COULD START RIDING IN AT TWO NINE SEVEN ONE SOUTH STATE PERSON WITH A GUN PERSON JUST BROKE INTO THE BUILDING SECURITY TOLD ME',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE <NEIGHBOR>',
#   ' WITH A GUN ROBBED THE STORE',
#   " HE'S GOT A TANK TOP GRAY JEANS GUN IN HIS WAIST AND A WHEEL CHAIR",
#   " WELL HE WAS SAYING SOMEBODY WAS ARMED WITH A GUN AND I CAN'T WE IF IT WAS A BONA FIDE ARMED ROBBERY WE'D HAVE TO DO PAPER IN THE FIELD",
#   " YEAH JUST CAUSE YOU'RE GOING TO THE AREA UM UNITS IN SIX JUST A HEADS UP PERSON WITH A GUN SEVEN FIVE AND PEORIA",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " SOMEONE'S IN A RED FOUR-DOOR SUV PASADENA ACURA SHOT HER IN THE LEG WITH A PAINTBALL GUN ",
#   ' RED VEHICLE WITH THE PAINT GUN',
#   " ALRIGHT AND ALSO HE'S A CONVICTED GUN OFFENDER",
#   ' UH THE GANG LEFT AND CAME BACK AND SOMEONE SAYS ONE OF THEM HAS A GUN',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   'SIMULCAST IS NOT AVAILABLE FOR A PERSON WITH A GUN THIRTY NINE EIGHTEEN WEST MONTROSE, THREE NINE ONE EIGHT WEST MONTROSE',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   'YOU WANNA START RIDING ON THAT SHE SAID SHE SAID CLEVELAND CALLED FIRST SAYING FEMALE NEEDS TO GO SHE’S HIGH AND THE FEMALE CALLED MS. WIGGINS SAYING THAT HER EX-BOYFRIEND CHOKED HER AND HAS A BB GUN THIRTY FOUR O SEVEN SUNNYSIDE THREE FOUR O SEVEN ON SUNNYSIDE',
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT'S GIVING A SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN",
#   "UNITS IN SEVENTEEN UNDER CITYWIDE IS GETTING A SLOW DOWN FOR THE PERSON WITH THE GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT'S ON SCENE GIVE THAT SLOW DOWN NOTHING FURTHER SEVENTEEN DISTRICT ZONE ONE CLEAR",
#   'MR. DOAS SAYS HE WAS SITTING IN HIS CAR AND WAS ROBBED AT GUN POINT MALE BLACK WITH A BLACK HOODIE',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR A PERSON WITH A GUN',
#   'UNITS IN SEVENTEEN ON THE CITY WIDE GETTING A SLOW DOWN FOR A PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT ASKING YOU TO SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT ON ONE CLEAR',
#   "FOR THE UNITS IN SIXTEEN AND ON THE CITY WIDE WE'RE GONNA TICKET A PERSON WITH A GUN AT GAYLE AND MILWAUKEE",
#   'CALLER SAYS HER SON SIXTEEN YEARS OF AGE WAS ROBBED AT GUN POINT AT THE SUPER MARKET BY TWO MALE HISPANICS ONE JACKET',
#   'THINKS IT WAS FIREWORKS OR GUN FIRE',
#   " OKAY WE'VE GOT A GUN RECOVERED OVER HERE",
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE',
#   "UH CHRISSY SAID SHE HEARD ONE SINGLE GUN SHOT IN THE AREA SO FAR IT'S THE ONLY CALL",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "HE GOT A CALL FROM ANOTHER EMPLOYEE THAT HE'S THAT HE'S LOOKING FOR A GUN AND IS PLANNING TO RETURN TO THE STORE",
#   "FORTY UNITS AT SIXTEEN IN ON A CITYWIDE WE'RE GONNA TAKE IT OVER PERSON WITH A GUN AT GALE AND MILWAUKEE IT'S A MCDONALD'S PARKING LOT TWO TO THREE MALE HISPANICS ARE INSIDE AND THERE'S A BLUE HONDA CRV",
#   'FOUR NINE ZERO ZERO BLOCK WEST PATTERSON AVENUE THREE GUN SHOTS HEARD ON THE CORNER BETWEEN PATTERSON AND LEMONT NOTHING FURTHER THAN ONE STATION CLEAR ',
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE ',
#   " YEAH WE'RE STILL OUTSIDE OF THE BUILDING WAITING FOR THE LADY TO TURN IN THE GUN",
#   ' DO YOU WANNA DO THIS GUN TURN IN',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   "YEAH WE'RE STILL IN FRONT OF THE BUILDING WAITING FOR A LADY TO TURN IN THE GUN",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   'SO YOU WANNA DO THIS GUN TURN IN',
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT YOU'LL HAVE TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN ",
#   'ELEVEN ROBERT TEN FOUR AGAIN SOME PERSON WITH A GUN',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND GOT A PERSON WITH A GUN',
#   'UNITS SEVENTEEN ON THE CITY WIDE SLOW DOWN FOR THE PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT IS LISTENING SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT IS ON ALL CLEAR',
#   ' UNITS AND EIGHTEEN ON THE CITYWIDE WE HAVE A CALL OF A PERSON WITH A GUN <AS PARK> TWENTY TWENTY ONE <EARTH> ',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION UH",
#   " GARY AND WINSTON IS THE OFFENDER PULLED A GUN ON HER AND THAT'S HER BOYFRIEND ALL THE INFO COMING IN",
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS AND HEADING SOUTHBOUND NOTHING FURTHER',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION",
#   ' YEAH ITS UH MALE WITH A GUN CALL OVER ON UH LA SALLE AND HUBBARD UHM',
#   'THE OFFENDER PULLED A GUN ON HER AND',
#   ' ALL UNITS IN TWO AND CITY WIDE IN TWO TWENTY FIVE WE HAVE A PERSON WITH A GUN. FIVE ONE ONE ZERO SOUTH CALUMET. FIVE ONE ONE ZERO SOUTH CALUMET. PER THE ANNONYMOUS CALLER ONE MALE BLACK BLUE JEANS SHIRT BLUE JEANS PASSED THE GUN TO SECOND MALE BLACK WEARING A WHITE TANK TOP AND GREY SHORTS BOTH STANDING OUTSIDE IN FRONT. THIS IS ZONE FIVE RADIO STATION',
#   ' DRIVER WAVED A GUN AT HIM WITH THREE UH THREE HISPANICS INSIDE THE CAR WITH HIM SAYS THEY WERE RIDING SLOWLY IN A BLUE PICKUP TRUCK LOCAL RED TYSON LAST SEEN GOING NORTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE <NEIGHBOR>',
#   ' WITH A GUN ROBBED THE STORE',
#   " HE'S GOT A TANK TOP GRAY JEANS GUN IN HIS WAIST AND A WHEEL CHAIR",
#   " WELL HE WAS SAYING SOMEBODY WAS ARMED WITH A GUN AND I CAN'T WE IF IT WAS A BONA FIDE ARMED ROBBERY WE'D HAVE TO DO PAPER IN THE FIELD",
#   " YEAH JUST CAUSE YOU'RE GOING TO THE AREA UM UNITS IN SIX JUST A HEADS UP PERSON WITH A GUN SEVEN FIVE AND PEORIA",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " SOMEONE'S IN A RED FOUR-DOOR SUV PASADENA ACURA SHOT HER IN THE LEG WITH A PAINTBALL GUN ",
#   ' RED VEHICLE WITH THE PAINT GUN',
#   " ALRIGHT AND ALSO HE'S A CONVICTED GUN OFFENDER",
#   ' UH THE GANG LEFT AND CAME BACK AND SOMEONE SAYS ONE OF THEM HAS A GUN',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   'SIMULCAST IS NOT AVAILABLE FOR A PERSON WITH A GUN THIRTY NINE EIGHTEEN WEST MONTROSE, THREE NINE ONE EIGHT WEST MONTROSE',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   'YOU WANNA START RIDING ON THAT SHE SAID SHE SAID CLEVELAND CALLED FIRST SAYING FEMALE NEEDS TO GO SHE’S HIGH AND THE FEMALE CALLED MS. WIGGINS SAYING THAT HER EX-BOYFRIEND CHOKED HER AND HAS A BB GUN THIRTY FOUR O SEVEN SUNNYSIDE THREE FOUR O SEVEN ON SUNNYSIDE',
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT'S GIVING A SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN",
#   "UNITS IN SEVENTEEN UNDER CITYWIDE IS GETTING A SLOW DOWN FOR THE PERSON WITH THE GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT'S ON SCENE GIVE THAT SLOW DOWN NOTHING FURTHER SEVENTEEN DISTRICT ZONE ONE CLEAR",
#   'MR. DOAS SAYS HE WAS SITTING IN HIS CAR AND WAS ROBBED AT GUN POINT MALE BLACK WITH A BLACK HOODIE',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR A PERSON WITH A GUN',
#   'UNITS IN SEVENTEEN ON THE CITY WIDE GETTING A SLOW DOWN FOR A PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT ASKING YOU TO SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT ON ONE CLEAR',
#   "FOR THE UNITS IN SIXTEEN AND ON THE CITY WIDE WE'RE GONNA TICKET A PERSON WITH A GUN AT GAYLE AND MILWAUKEE",
#   'CALLER SAYS HER SON SIXTEEN YEARS OF AGE WAS ROBBED AT GUN POINT AT THE SUPER MARKET BY TWO MALE HISPANICS ONE JACKET',
#   'THINKS IT WAS FIREWORKS OR GUN FIRE',
#   " OKAY WE'VE GOT A GUN RECOVERED OVER HERE",
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE',
#   "UH CHRISSY SAID SHE HEARD ONE SINGLE GUN SHOT IN THE AREA SO FAR IT'S THE ONLY CALL",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "HE GOT A CALL FROM ANOTHER EMPLOYEE THAT HE'S THAT HE'S LOOKING FOR A GUN AND IS PLANNING TO RETURN TO THE STORE",
#   "FORTY UNITS AT SIXTEEN IN ON A CITYWIDE WE'RE GONNA TAKE IT OVER PERSON WITH A GUN AT GALE AND MILWAUKEE IT'S A MCDONALD'S PARKING LOT TWO TO THREE MALE HISPANICS ARE INSIDE AND THERE'S A BLUE HONDA CRV",
#   'FOUR NINE ZERO ZERO BLOCK WEST PATTERSON AVENUE THREE GUN SHOTS HEARD ON THE CORNER BETWEEN PATTERSON AND LEMONT NOTHING FURTHER THAN ONE STATION CLEAR ',
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE ',
#   " YEAH WE'RE STILL OUTSIDE OF THE BUILDING WAITING FOR THE LADY TO TURN IN THE GUN",
#   ' DO YOU WANNA DO THIS GUN TURN IN',
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MONTROSE THREE TWO ZERO ONE MONTROSE AT THE BP STATION. RODRIGO MENDOZA SAYS THERE WAS A GUY WITH A GUN AND A BLACK CAR THAT'S FOLLOWING HIM. HE'S STILL IN THE AREA, CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MONTROSE THREE TWO ZERO ONE MONTROSE AT THE BP STATION. RODRIGO MENDOZA SAYS THERE WAS A GUY WITH A GUN AND A BLACK CAR THAT'S FOLLOWING HIM. HE'S STILL IN THE AREA, CALLER'S WAITING INSIDE THE GAS STATION",
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   "YEAH WE'RE STILL IN FRONT OF THE BUILDING WAITING FOR A LADY TO TURN IN THE GUN",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   'SO YOU WANNA DO THIS GUN TURN IN',
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT YOU'LL HAVE TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN ",
#   'ELEVEN ROBERT TEN FOUR AGAIN SOME PERSON WITH A GUN',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND GOT A PERSON WITH A GUN',
#   'UNITS SEVENTEEN ON THE CITY WIDE SLOW DOWN FOR THE PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT IS LISTENING SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT IS ON ALL CLEAR',
#   ' UNITS AND EIGHTEEN ON THE CITYWIDE WE HAVE A CALL OF A PERSON WITH A GUN <AS PARK> TWENTY TWENTY ONE <EARTH> ',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION UH",
#   " GARY AND WINSTON IS THE OFFENDER PULLED A GUN ON HER AND THAT'S HER BOYFRIEND ALL THE INFO COMING IN",
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS AND HEADING SOUTHBOUND NOTHING FURTHER',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION",
#   ' YEAH ITS UH MALE WITH A GUN CALL OVER ON UH LA SALLE AND HUBBARD UHM',
#   'THE OFFENDER PULLED A GUN ON HER AND',
#   ' ALL UNITS IN TWO AND CITY WIDE IN TWO TWENTY FIVE WE HAVE A PERSON WITH A GUN. FIVE ONE ONE ZERO SOUTH CALUMET. FIVE ONE ONE ZERO SOUTH CALUMET. PER THE ANNONYMOUS CALLER ONE MALE BLACK BLUE JEANS SHIRT BLUE JEANS PASSED THE GUN TO SECOND MALE BLACK WEARING A WHITE TANK TOP AND GREY SHORTS BOTH STANDING OUTSIDE IN FRONT. THIS IS ZONE FIVE RADIO STATION',
#   ' DRIVER WAVED A GUN AT HIM WITH THREE UH THREE HISPANICS INSIDE THE CAR WITH HIM SAYS THEY WERE RIDING SLOWLY IN A BLUE PICKUP TRUCK LOCAL RED TYSON LAST SEEN GOING NORTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE',
#   'PERSON WITH A GUN TWENTY NINE SEVENTY ONE SOUTH STATE TWO NINE SEVEN ONE SOUTH ',
#   'TWO THREE HENRY IF YOU COULD START RIDING IN AT TWO NINE SEVEN ONE SOUTH STATE PERSON WITH A GUN PERSON JUST BROKE INTO THE BUILDING SECURITY TOLD ME',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE <NEIGHBOR>',
#   ' WITH A GUN ROBBED THE STORE',
#   " HE'S GOT A TANK TOP GRAY JEANS GUN IN HIS WAIST AND A WHEEL CHAIR",
#   " WELL HE WAS SAYING SOMEBODY WAS ARMED WITH A GUN AND I CAN'T WE IF IT WAS A BONA FIDE ARMED ROBBERY WE'D HAVE TO DO PAPER IN THE FIELD",
#   " YEAH JUST CAUSE YOU'RE GOING TO THE AREA UM UNITS IN SIX JUST A HEADS UP PERSON WITH A GUN SEVEN FIVE AND PEORIA",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " SOMEONE'S IN A RED FOUR-DOOR SUV PASADENA ACURA SHOT HER IN THE LEG WITH A PAINTBALL GUN ",
#   ' RED VEHICLE WITH THE PAINT GUN',
#   " ALRIGHT AND ALSO HE'S A CONVICTED GUN OFFENDER",
#   ' UH THE GANG LEFT AND CAME BACK AND SOMEONE SAYS ONE OF THEM HAS A GUN',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   'SIMULCAST IS NOT AVAILABLE FOR A PERSON WITH A GUN THIRTY NINE EIGHTEEN WEST MONTROSE, THREE NINE ONE EIGHT WEST MONTROSE',
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   'YOU WANNA START RIDING ON THAT SHE SAID SHE SAID CLEVELAND CALLED FIRST SAYING FEMALE NEEDS TO GO SHE’S HIGH AND THE FEMALE CALLED MS. WIGGINS SAYING THAT HER EX-BOYFRIEND CHOKED HER AND HAS A BB GUN THIRTY FOUR O SEVEN SUNNYSIDE THREE FOUR O SEVEN ON SUNNYSIDE',
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   "TOMOCAST IS NOT AVAILABLE SEVENTEEN TWENTY THREE ROBERT UNITS IN SEVENTEEN ON THE CITY ON THE ZONE. GOT A PERSON WITH A GUN ITS THIRTY SEVEN THIRTY WEST LELAND THREE SEVEN THREE ZERO LELAND MALE BLACK WITH A WHITE T-SHIRT ON. HE'S IN FRONT WITH A GUN THREATENING PEOPLE",
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT'S GIVING A SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN",
#   "UNITS IN SEVENTEEN UNDER CITYWIDE IS GETTING A SLOW DOWN FOR THE PERSON WITH THE GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT'S ON SCENE GIVE THAT SLOW DOWN NOTHING FURTHER SEVENTEEN DISTRICT ZONE ONE CLEAR",
#   'MR. DOAS SAYS HE WAS SITTING IN HIS CAR AND WAS ROBBED AT GUN POINT MALE BLACK WITH A BLACK HOODIE',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR A PERSON WITH A GUN',
#   'UNITS IN SEVENTEEN ON THE CITY WIDE GETTING A SLOW DOWN FOR A PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT ASKING YOU TO SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT ON ONE CLEAR',
#   "FOR THE UNITS IN SIXTEEN AND ON THE CITY WIDE WE'RE GONNA TICKET A PERSON WITH A GUN AT GAYLE AND MILWAUKEE",
#   'CALLER SAYS HER SON SIXTEEN YEARS OF AGE WAS ROBBED AT GUN POINT AT THE SUPER MARKET BY TWO MALE HISPANICS ONE JACKET',
#   'THINKS IT WAS FIREWORKS OR GUN FIRE',
#   " OKAY WE'VE GOT A GUN RECOVERED OVER HERE",
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE',
#   "UH CHRISSY SAID SHE HEARD ONE SINGLE GUN SHOT IN THE AREA SO FAR IT'S THE ONLY CALL",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MANTRIL THREE TWO ZERO ONE MANTRIL THERES A BEE PEE STATION RODRIGO MENDOZA SAID THERE WAS A GUY WITH A GUN IN A BLACK CAR THAT'S FOLLOWING THEM HE'S STILL IN THE AREA CALLER'S WAITING INSIDE THE GAS STATION",
#   "HE GOT A CALL FROM ANOTHER EMPLOYEE THAT HE'S THAT HE'S LOOKING FOR A GUN AND IS PLANNING TO RETURN TO THE STORE",
#   "FORTY UNITS AT SIXTEEN IN ON A CITYWIDE WE'RE GONNA TAKE IT OVER PERSON WITH A GUN AT GALE AND MILWAUKEE IT'S A MCDONALD'S PARKING LOT TWO TO THREE MALE HISPANICS ARE INSIDE AND THERE'S A BLUE HONDA CRV",
#   'FOUR NINE ZERO ZERO BLOCK WEST PATTERSON AVENUE THREE GUN SHOTS HEARD ON THE CORNER BETWEEN PATTERSON AND LEMONT NOTHING FURTHER THAN ONE STATION CLEAR ',
#   ' OKAY JUST TO BE CLEAR ON THIS GUN RECOVERED OUT OF WHICH VEHICLE ',
#   " YEAH WE'RE STILL OUTSIDE OF THE BUILDING WAITING FOR THE LADY TO TURN IN THE GUN",
#   ' DO YOU WANNA DO THIS GUN TURN IN',
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MONTROSE THREE TWO ZERO ONE MONTROSE AT THE BP STATION. RODRIGO MENDOZA SAYS THERE WAS A GUY WITH A GUN AND A BLACK CAR THAT'S FOLLOWING HIM. HE'S STILL IN THE AREA, CALLER'S WAITING INSIDE THE GAS STATION",
#   "GOT A PERSON WITH A GUN THIRTY TWO OH ONE MONTROSE THREE TWO ZERO ONE MONTROSE AT THE BP STATION. RODRIGO MENDOZA SAYS THERE WAS A GUY WITH A GUN AND A BLACK CAR THAT'S FOLLOWING HIM. HE'S STILL IN THE AREA, CALLER'S WAITING INSIDE THE GAS STATION",
#   'CALLER CLAIMS THE SISTER PULLED A GUN ON HER',
#   "YEAH WE'RE STILL IN FRONT OF THE BUILDING WAITING FOR A LADY TO TURN IN THE GUN",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   "ALRIGHT I GOT YOU GOING OVER TO TWENTY TWO, I GOT A GUN TURN IN FOR ANYBODY THAT WANT IT THREE FIVE FOUR THREE NORTH MI THE PARENT LIZ PORTON SHE HAS THE GUN AND THE APPARTMENT BELONGS TO SOMEONE THAT'S LIVING WITH HER HOWEVER HE'S ON ELECTRIC MONITERING AT THIS TIME ",
#   'SO YOU WANNA DO THIS GUN TURN IN',
#   'ELEVEN ROBERT TEN FOUR WE GOT SOME PERSON WITH A GUN',
#   "SEVENTEEN TWENTY THREE ROBERT YOU'LL HAVE TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND FOR THE PERSON WITH A GUN ",
#   'ELEVEN ROBERT TEN FOUR AGAIN SOME PERSON WITH A GUN',
#   'SEVENTEEN TWENTY THREE ROBERT DO YOU HAPPEN TO SLOW DOWN FOR THIRTY SEVEN THIRTY LELAND GOT A PERSON WITH A GUN',
#   'UNITS SEVENTEEN ON THE CITY WIDE SLOW DOWN FOR THE PERSON WITH A GUN THIRTY SEVEN THIRTY LELAND SLOW IT DOWN TWENTY THREE ROBERT IS LISTENING SLOW DOWN NOTHING FURTHER SEVENTEENTH DISTRICT IS ON ALL CLEAR',
#   ' UNITS AND EIGHTEEN ON THE CITYWIDE WE HAVE A CALL OF A PERSON WITH A GUN <AS PARK> TWENTY TWENTY ONE <EARTH> ',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION UH",
#   " GARY AND WINSTON IS THE OFFENDER PULLED A GUN ON HER AND THAT'S HER BOYFRIEND ALL THE INFO COMING IN",
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' UNITS IN EIGHTEEN ON CITYWIDE GETTING A PERSON WITH A GUN AT LA SALLE AND HUBBARD HUBBARD AND LA SALLE SAYS A MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS HEADING SOUTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK WITH A GUN IN HIS RIGHT POCKET WEARING A BLACK SHIRT GRAY JOGGING PANTS HAS BRAIDS AND HEADING SOUTHBOUND NOTHING FURTHER',
#   " FOR THE CALL OF A PERSON WITH A GUN WE'RE ALSO GETTING A LOCATION",
#   ' YEAH ITS UH MALE WITH A GUN CALL OVER ON UH LA SALLE AND HUBBARD UHM',
#   'THE OFFENDER PULLED A GUN ON HER AND',
#   ' ALL UNITS IN TWO AND CITY WIDE IN TWO TWENTY FIVE WE HAVE A PERSON WITH A GUN. FIVE ONE ONE ZERO SOUTH CALUMET. FIVE ONE ONE ZERO SOUTH CALUMET. PER THE ANNONYMOUS CALLER ONE MALE BLACK BLUE JEANS SHIRT BLUE JEANS PASSED THE GUN TO SECOND MALE BLACK WEARING A WHITE TANK TOP AND GREY SHORTS BOTH STANDING OUTSIDE IN FRONT. THIS IS ZONE FIVE RADIO STATION',
#   ' DRIVER WAVED A GUN AT HIM WITH THREE UH THREE HISPANICS INSIDE THE CAR WITH HIM SAYS THEY WERE RIDING SLOWLY IN A BLUE PICKUP TRUCK LOCAL RED TYSON LAST SEEN GOING NORTHBOUND NOTHING FURTHER ZONE FOUR CLEAR',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE',
#   'PERSON WITH A GUN TWENTY NINE SEVENTY ONE SOUTH STATE TWO NINE SEVEN ONE SOUTH ',
#   'TWO THREE HENRY IF YOU COULD START RIDING IN AT TWO NINE SEVEN ONE SOUTH STATE PERSON WITH A GUN PERSON JUST BROKE INTO THE BUILDING SECURITY TOLD ME',
#   ' MALE BLACK IN HIS THIRTIES WITH A GUN ROBBED THE STORE <NEIGHBOR>',
#   ' WITH A GUN ROBBED THE STORE',
#   " HE'S GOT A TANK TOP GRAY JEANS GUN IN HIS WAIST AND A WHEEL CHAIR",
#   " WELL HE WAS SAYING SOMEBODY WAS ARMED WITH A GUN AND I CAN'T WE IF IT WAS A BONA FIDE ARMED ROBBERY WE'D HAVE TO DO PAPER IN THE FIELD",
#   " YEAH JUST CAUSE YOU'RE GOING TO THE AREA UM UNITS IN SIX JUST A HEADS UP PERSON WITH A GUN SEVEN FIVE AND PEORIA",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " IT'S A PAINTBALL GUN PAINTBALL GUN",
#   " SOMEONE'S IN A RED FOUR-DOOR SUV PASADENA ACURA SHOT HER IN THE LEG WITH A PAINTBALL GUN ",
#   ' RED VEHICLE WITH THE PAINT GUN',
#   " ALRIGHT AND ALSO HE'S A CONVICTED GUN OFFENDER",
#   ' UH THE GANG LEFT AND CAME BACK AND SOMEONE SAYS ONE OF THEM HAS A GUN',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   ' ALRIGHT UNITS IN SIX AND CITYWIDE WE GOT A PERSON WITH A GUN PERSON WITH A GUN IN NINETY-SECOND AND COTTAGE GROVE',
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO",
#   " USE CAUTION HE HAD A GUN THEN SAID SHE DIDN'T SEE THE GUN SO"]}

# %%
def words_heat_map(comb: tuple, transcripts: list):
    """
    plot the heatmap of the transcripts that include a specific code
    light cell means high probability of co-occurance
    """
    empty_map = np.zeros((len(long_text), len(long_text)))
    
    transcrip = ' '.join(transcripts)
    transcrip = [word.replace('<X>', '').replace('<x>', '') for word in transcrip.split(' ')]
    transcrip = [re.sub('[\(\[].*?[\)\]]', '', word.strip()) for word in transcrip if word != ''] 
    transcrip = [re.sub('[^a-zA-Z0-9]', '', word.strip()) for word in transcrip if word != '']
    transcrip = [word for word in transcrip if word not in numwords]
    transcrip = [word for word in transcrip if word not in stopword_list]
    transcrip = list(set(transcrip))[1:]
    transcrip.insert(0, '*')
    
    # according to bayes rule: p(A and B) = p(A|B) * p(B)
    # heat_map = empty_map.copy()
    heat_map = np.zeros((len(transcrip), len(transcrip)))
    for a in range(len(transcrip)):
        for b in range(i+1, len(transcrip)):
            if a == b:
                continue
            # index_a = long_text.index(transcrip[a])
            # index_b = long_text.index(transcrip[b])
            # has_b = [trans for trans in transcripts if long_text[index_b] in trans]
            has_b = [trans for trans in transcripts if transcrip[b] in trans]
            if has_b != []:
                if transcrip[a] == '*':
                    has_a_when_b = [trans for trans in has_b if ' '.join(list(comb)) in trans]
                else:
                    # has_a_when_b = [trans for trans in has_b if long_text[index_a] in trans]
                    has_a_when_b = [trans for trans in has_b if transcrip[a] in trans]
                cond_prob = len(has_a_when_b) / len(has_b)
                prob_b = len(has_b) / len(transcripts)
                # heat_map[index_a, index_b] = cond_prob * prob_b
                # heat_map[index_b, index_a] = heat_map[i, j]
                heat_map[a, b] = cond_prob * prob_b
                heat_map[b, a] = heat_map[a, b]
    # plot the heatmap
    plt.figure(figsize=(10, 10))
    sns.heatmap(heat_map, square=True, yticklabels=transcrip, xticklabels=transcrip, cbar=False)
    plt.show()
    return heat_map

# %%
# matrix1 = words_heat_map(('ONE', 'TWO', 'THREE'),
#                         comb_dict[('ONE', 'TWO', 'THREE')])
matrix1 = words_heat_map(('ZERO', 'NINE'),
                        comb_dict[('ZERO', 'NINE')])

# %%
text_with_special_charc = []
for transcript in text:
    if '[' in transcript or '<' in transcript or '(' in transcript:
        text_with_special_charc.append(transcript)

# %%
# clean text
porter = nltk.PorterStemmer()
clean_text = []
for transcript in text:
    # remove those only have <>
    transcript = transcript.replace('<X>', '').replace('<x>', '')
    # remove text inside [] and ()
    transcript = re.sub('[\(\[].*?[\)\]]', '', transcript)
    # remove empty
    if transcript == '':
        continue
    # clean
    splited = [re.sub('[^a-zA-Z0-9]', '', word) for word in transcript.split(' ')]
    stemed = [porter.stem(word) for word in splited if len(word) != 0 and word != '']
    clean_text.append(' '.join(stemed))

# %%
# remove stopword
stopword_list = ['on', 'the', 'a', 'and', 'on', 'uh', 'in', 'to', 'at', 'that', 'for', 'is', 'with', 'of', 'oh', '', 'and']
second_clean_text = []
for transcript in clean_text:
    words = [word for word in transcript.split(' ') if word not in stopword_list]
    second_clean_text.append(' '.join(words))

# %%
# 
word_dict = ' '.join(second_clean_text).split(' ')
freq = nltk.FreqDist(word_dict)
message_bag = pd.DataFrame(freq.most_common(), columns=['word_name', 'count'])
total_count = sum(message_bag['count'])
message_bag['tf'] = message_bag['count'] / total_count
plt.figure(figsize=(12, 8))
plt.bar(message_bag.head(10)['word_name'], message_bag.head(10)['count'])
plt.show()

# %%
text = ' '.join(word_dict)
wordcloud = WordCloud().generate(text)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# use LDA
list_of_list_of_tokens = [line.split(' ') for line in second_clean_text]
dictionary_LDA = gensim.corpora.Dictionary(list_of_list_of_tokens)
dictionary_LDA.filter_extremes(no_below=3)
corpus = [dictionary_LDA.doc2bow(list_of_tokens) for list_of_tokens in list_of_list_of_tokens]
num_topics = 5
lda_model = gensim.models.LdaModel(corpus, num_topics=num_topics,
                                   id2word=dictionary_LDA,
                                   passes=4, alpha=[0.01]*num_topics,
                                   eta=[0.01]*len(dictionary_LDA.keys()))
vis = pyLDAvis.gensim_models.prepare(topic_model=lda_model, corpus=corpus, dictionary=dictionary_LDA)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis)
# Out:
# /software/python-anaconda-2021.05-el8-x86_64/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el32115431398183723295367462995140"></div>
# <script type="text/javascript">
#
# var ldavis_el32115431398183723295367462995140_data = {"mdsDat": {"x": [0.2866951562958143, 0.2912221638826153, -0.26441861904188657, -0.30948307174479356, -0.004015629391749392], "y": [0.05680893595031853, 0.1543621451428574, 0.021907184585277868, 0.1845820710256795, -0.4176603367041331], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [25.52052697931597, 25.397716038121377, 23.419918475325627, 16.578375595758338, 9.083462911478685]}, "tinfo": {"Term": ["four", "robert", "ten", "one", "six", "twenti", "", "two", "three", "you", "five", "thirti", "seven", "eight", "nine", "zero", "sixteen", "can", "eighteen", "seventeen", "i", "eleven", "twelv", "ok", "thirteen", "alright", "get", "have", "he", "we", "can", "squad", "fourteen", "me", "gonna", "do", "need", "here", "guy", "ill", "put", "give", "hey", "who", "disregard", "where", "way", "hold", "station", "domest", "ani", "job", "make", "ambul", "think", "ride", "stand", "send", "anyon", "victim", "yeah", "if", "help", "you", "we", "have", "right", "i", "over", "were", "dont", "pleas", "your", "okay", "are", "got", "be", "up", "what", "it", "there", "um", "go", "well", "out", "an", "call", "", "get", "he", "male", "wa", "black", "say", "so", "know", "she", "o", "white", "let", "caller", "look", "person", "vehicl", "front", "shirt", "progress", "tri", "further", "hi", "them", "ha", "as", "shot", "inform", "noth", "again", "no", "her", "come", "from", "unit", "call", "they", "it", "just", "there", "femal", "park", "i", "six", "five", "seven", "eight", "nine", "zero", "nineti", "eighti", "adam", "boy", "sixti", "david", "charli", "fourti", "eddi", "john", "thousand", "sam", "paul", "key", "neg", "log", "valid", "r", "fine", "lincoln", "interact", "ran", "commun", "lake", "avenu", "fifti", "forti", "west", "one", "three", "two", "event", "south", "first", "hundr", "number", "north", "east", "four", "thirti", "seventi", "eighteen", "robert", "twenti", "sixteen", "seventeen", "ahead", "rob", "chicago", "teen", "info", "fifth", "threaten", "hispan", "pull", "correct", "exchang", "hear", "attempt", "truck", "point", "brown", "suppos", "relat", "b", "place", "move", "drop", "e", "sit", "william", "toyota", "twelv", "thirteen", "eleven", "thirti", "eighteen", "seventi", "one", "two", "three", "go", "forti", "time", "ten", "ok", "thank", "copi", "area", "maam", "third", "ye", "resid", "our", "burglar", "veri", "green", "would", "id", "man", "onli", "updat", "advis", "x", "kid", "child", "foot", "georg", "van", "near", "cicero", "use", "low", "broke", "traffic", "four", "stop", "alright", "sure", "sir", "mission", "you", "alarm", "okay", "assist", "no", "good", "did"], "Freq": [77725.0, 55605.0, 28101.0, 72461.0, 44867.0, 28038.0, 36617.0, 46662.0, 42388.0, 33550.0, 24358.0, 26062.0, 19036.0, 17379.0, 14794.0, 14068.0, 9836.0, 11959.0, 11374.0, 8435.0, 15698.0, 8746.0, 7506.0, 5282.0, 7036.0, 9244.0, 8810.0, 11571.0, 8695.0, 10668.0, 11959.679681108173, 5239.8025667351885, 5188.714181141827, 5119.072362085082, 5050.316332856291, 4754.1422573857735, 3819.224129125995, 3788.6182801695795, 3694.1172343230205, 3085.872459484747, 2533.5257634270174, 2347.8311056869484, 2159.8687811939003, 1994.323322410051, 1960.2653940904174, 1943.2455752533083, 1810.1856092011215, 1599.9777538202113, 1642.1977893366566, 1324.7516932485269, 1164.9549096629078, 1147.5956873698074, 1140.2874546910925, 1128.8489889745142, 1085.8234185028543, 1044.0493574478282, 1039.6003445898752, 1011.2727075034375, 916.5774635287739, 916.2255552437746, 6402.921132926281, 4154.273664951363, 1407.360460069053, 29755.69677130021, 9771.215155561114, 10401.754920685566, 2680.317151565636, 13211.828897052836, 6708.482415557935, 6837.76890947747, 2335.2372497617844, 3191.754579481914, 6316.70649600966, 5142.203309522421, 4829.8274549990165, 6735.139724775584, 5096.474829592601, 3599.8461280188217, 4224.568348065879, 9636.280211714655, 6431.117096029655, 4619.640689852105, 6919.828210378591, 3874.9378083384777, 4204.171292 ...

# %%
# detect combination of numbers
# Out:
# ['radioshop test one two three four five five four three two one radio shop test',
#  'one two one two',
#  'unit come',
#  'zone one citi five',
#  'okay thank thi radio shop test how do you copi one two three four five',
#  'five four three two one loud clear',
#  'zero nine thirti five hour loud clear',
#  'one two tre cuatro',
#  'sixteen seven david zone one five citi wide five b five',
#  'radioshop test one',
#  'loud clear sir',
#  'nine fourti nine',
#  'uno do tre cuatro cinco loud clear',
#  'radio shop test one two three four five',
#  'five four three two one radio shop test',
#  'loud clear one two three four five',
#  'sixteen twenti four robert',
#  'two four robert',
#  'we found taxi driver it go be',
#  'sixteen twenti one robert',
#  'six two one robert',
#  'suspic person seventi one hundr mason call say three male hoodi ride bike check car door one gray either gray or white hoodi other two are dark hoodieshead north bound',
#  'ten four',
#  'seven eleven',
#  'eleven robert',
#  'thirti minut',
#  'seventeen thirteen robert',
#  'seventeen thirteen robert',
#  'servic brown line fourti seven fifti five kimbal three male are refus get off train',
#  'ten four',
#  'six seventeen twenti two robert',
#  'twenti two robert',
#  'fourti ten lawrenc walgreen gari say he got male black about 35 black t shirt hold item bag',
#  'seven nine five robert',
#  'nineti five robert',
#  'can i get traffic stop central park carmen pleas',
#  'seventeen twelv robert anyth callback',
#  'line been busi twice so far',
#  'give them nineteen call em back',
#  'sixteen thirti three robert',
#  'one six three three robert',
#  'thirti three robert',
#  'suspic person bernic menard bernic menard male black red shirt cari white shop bag been walk around circl over thirti minut talk themselv yell not sure what wrong them',
#  'twenti three robert',
#  'six two three robert',
#  'can i get time',
#  'seventi two robert',
#  'seven seventi two robert',
#  'traffic stop montros maplewood',
#  'hi seventeen thirti three ro er sixteen thirti three robert',
#  'yeah your caller from bernic menard call back',
#  'guy say now male black red tshirt cari bag probabl drunk talk himself but he get neighbor porch fifti eight two byron now',
#  'seventeen three robert',
#  'seven two three rob',
#  'yeah okay',
#  'teen thirti one robert',
#  'thirti one robert',
#  'stop by car harlem spool',
#  'seventeen twelv robert',
#  'batteri progress thirti two fifti five victoria three male fight middl street',
#  'seventeen twenti two robert',
#  'twenti two robert',
#  'nineteen can we get thirti nine seventeen',
#  'sure',
#  'nine five robert',
#  'nineti five robert',
#  'can you show me head over twelv robert job pleas',
#  'sixteen thirteen robert',
#  'yeah take ride byer harlem brenmar caller car smoke fire fire over there',
#  'nine five robert',
#  'nineti five robert',
#  'slow down there no one down here fight',
#  'not surpris if by chanc somebodi els wa go thirti two fifti five paris it slow down',
#  'thirteen robert',
#  'thirteen robert',
#  'yeah fire scene it cook',
#  'okay',
#  'it actual harlem or it brenmar',
#  'thirteen robert',
#  'go ahead',
#  'nine zero six six two it yeah it bermont',
#  'okay give me plate again',
#  'nanci eight nine zero six six two',
#  'alright',
#  'it wa toyota seven toyota',
#  'alright owner car miguel diaz',
#  'it hi mom car',
#  'her name caludia gonzalez',
#  'sixteen thirti two robert',
#  'thirti three robert',
#  'call thirti minut five six four two irv',
#  'alright',
#  'seventeen twelv robert',
#  'robert',
#  'check wildev fifti three twenti four kedzi caller rambl about woman man cant make out what he wa say but he want polic right now',
#  'sixteen twenti four robert',
#  'twenti four robert',
#  'radioshop test one two thre four five five four three two one how do you copi radio shop test one two three four five',
#  'go ahead thi radio shop',
#  'one six six two boy',
#  'radio test',
#  'seven two two rob',
#  'sevnteen twenti two robert traffic stop fourti four four lawrenc',
#  'ten four',
#  'six one two robert',
#  'sixteen twelv rob',
#  'traffic stop north',
#  'seventeen twenti three robert',
#  'two three robert',
#  'take ride domest four six nine five north',
#  'four six nine five north kayson basement he hi cousin',
#  'boyfirend smack her window refus leav',
#  'male hispan white shirt bicycl',
#  'ten four',
#  'seventeen twenti two robert you can show us clear well go domest',
#  'alright ten four',
#  'seven two three two two go take thi domest okay',
#  'okay ten four',
#  'seventeen thirteen robert can you show us go',
#  'sixteen six two one',
#  'six six one',
#  'can you log out then log back pleas',
#  'alright ten four tri it now',
#  'sixteen one robert',
#  'sixteen',
#  'yeah we just got phone call from secur person over re north i guess they had somebodi turn some item them sound like probabl narcot if you could send car over there recov them from them',
#  'who should we see maam where would they be',
#  'sure um theyll be julio he secur guard he said go main lobbi off telcott go entranc number one',
#  'alright ten four well make',
#  'thank you so much',
#  'no problem',
#  'sixteen sixti one adam',
#  'sixti one adam come',
#  'can you log off can you log back',
#  'no problem',
#  'seven nine five robert',
#  'seventeen nineti five robert go ahead',
#  'can you get traffic stop montros elson pleas',
#  'ten four',
#  'ay grab me water',
#  'alright',
#  'teen thirteen robert',
#  'sixteen thirteen rob',
#  'sixteen thirti four robert traffic stop rosco narangansett',
#  'ten four sixteen thirti four robert',
#  'just some inform zone come from twenti fifth district from menard wilmington reckless driver drive honda lmn licens plate nine six five two three zero eight were head toward belmont from menard noth further just inform zone',
#  'sixteen twelv robert',
#  'six one two robert',
#  'i have you go check re north see julio secur um entranc one off tolcott he ha some item need be turn into polic',
#  'sixteen six two one fresco',
#  'six two one go',
#  'david eddi still us as well',
#  'me just add him well just add him david',
#  'sixteen sixti one david imma log you off so you can log back too',
#  'okay squad think im ride sixteen sixti one',
#  'seventeen twelv robert',
#  'teen twelv robert',
#  'sex offens robert state hi sister went date male she met onlin tri sexual assualt her she now vehicl brother theyr follow offend head north kedzi white chrysler 200 plate adam eddi six zero four nine nine call taker advis them not follow she refus em',
#  'plate come back louis twenti eight fifti west glen lake avenu chicago white 2015 chrysler',
#  'sixteen eleven robert',
#  'sixteen eleven robert',
#  'okay ten four thank',
#  'seventeen twenti four robert',
#  'robert',
#  'weve got disturb montros albani fernando state driver cab number twenti six sixti four refus let him out noth further',
#  'teen twenti four robert',
#  'seventeen twenti four robert',
#  'do you have contact there no one over here',
#  'we tri give him call ten five',
#  'seventeen twenti four robert she montros richmond now montros richmond',
#  'aight aight okay',
#  'seventeen twelv robert your call back them',
#  'yeah there number',
#  'seventeen twenti four robert',
#  'two four robert',
#  'we found taxi driver',
#  'ten four',
#  'seven three two robert',
#  'can i have vin number',
#  'alright there your number i need you make notif mount prospect pd 3741',
#  'they want you check out domest batteri offend might be uncl hous address somewher',
#  'hi name gon paul gonzalez',
#  'fourteen may nineti four do not might be drive nineti nine white chevi prism tom 14170',
#  'might be park out there if it let me know',
#  'also um if he there mount prospect want us take him into custodi theyll come down get him',
#  'so let me know what you find out there but i do not have uncl name or an apart number or anyth',
#  'ten thirteen robert',
#  'thirteen robert',
#  'five three three five',
#  'one thirti nine',
#  'twenti three robert',
#  'twenti three robert',
#  'we have one us thirteen robert were gonna same thing',
#  'sixteen thirti two robert',
#  'robert',
#  'yeah over now ive got fire roll',
#  'guy possibl overdos coke basement bathroom floor',
#  'let me know if thi one same or if their two separ chap',
#  'were here right now',
#  'seven two three robert',
#  'two three robert',
#  'were told saint loui loud music come from alley between saint loui drake',
#  'ten four',
#  'fifeteen fourteen robert',
#  'fourteen robert',
#  'number you um you want cta check platform come one blue line they number',
#  'you got em your clear',
#  'six one two robert',
#  'twelv robert',
#  'transfer five five nine two six',
#  'sixteen thirti two robert',
#  'thirti two robert',
#  'theyv been call um an em whole separ situat',
#  'okay',
#  'thirteen robert',
#  'thirteen robert',
#  'yeah my mess twenti four mess were unrel um twenti three robert thing',
#  'okay so they are two separ job then',
#  'veri close',
#  'so im clear',
#  'alright let me put twenti four then right one',
#  'three robert',
#  'sixteen twenti three robert',
#  'were go be look femal thirti six fourti one west alt field',
#  'i didnt get static your radio tri it again your someth alt go',
#  'reloc three femal thirti fifth thirti one west west alt field permiss from it not relat thi incid',
#  'so sixteen thirti robert',
#  'sixteen thirti robert',
#  'go ahead',
#  'yeah can twenti three take those three femal thirti six hundr block alton',
#  'ten four',
#  'alright go ahead dont get lost put your blinder',
#  'seven three one robert',
#  'thirti one robert',
#  'pressur safeti',
#  'harsh',
#  'seventeen eleven robert',
#  'sixti two fifti lincoln see mario north park drunk peopl who he refus rent room',
#  'seventeen thrti two robert',
#  'thrti two rob',
#  'build front door lock ther no way get no no where around here',
#  'okay thank you just dont do anyth it until i can get rid it send it back mount prospect',
#  'sixteen thirti robert',
#  'go ahead',
#  'yeah ive got request supervisor you fourti four hundr menard regard twenti four job ms portillo say she want supervisor becaus offic are not search arrest peopl who assualt her stole her necklac',
#  'alright ill meet twenti four somewher along way over there',
#  'no theyr still scene over there too',
#  'sixteen thirti one robert',
#  'sixteen thirti one robert were about',
#  'sure where',
#  'what address it will be fifti two thirti two narragansett',
#  'sixteen twenti one robert',
#  'one robert',
#  'six fourteen robert',
#  'six fourteen robert',
#  'fourteen robert take ride em',
#  'eight five three five west montaga chicago ohar male we got twenti year old male pass out bench fire respond ask an assist',
#  'seven two three robert',
#  'seven two three robert come',
#  'could i get person pleas',
#  'sixteen thirti robert',
#  'sixteen thirti robert go ahead',
#  'do me favor send one more car over here no emerg okay',
#  'sixteen thirti two robert',
#  'fourti four hundr north menard scene close fourti four hundr north menard thirti robert need one car no emerg',
#  'seventeen nine five robert',
#  'seventeen nineti five robert',
#  'wonder if you can have avail sergeant take look my traffic crash report pleas',
#  'sergeant seventeen seventeen nineti five robert',
#  'seventeen',
#  'sixteen thirti robert you okay ye',
#  'you tri come',
#  'one seven two three',
#  'im clear',
#  'seventeen twenti four',
#  'seventeen four commerci fourti fourti nine north richmond felma construct polic be dispatch arriv you',
#  'seven two three',
#  'one seven two three',
#  'robert twenti four commerci fourti fourti nine north richmond',
#  'felma construct',
#  'seventeen twelv',
#  'hello',
#  'violat fourti eight fifteen north aber without permit',
#  'seven thirti two',
#  'ten eight hundr block north keyston park adjac school there citizen let dog run around without leash',
#  'seven two two',
#  'seven two two i cant copi but seven thirti two you need backup',
#  'seven two two you tri get an r d number',
#  'we cant copi all',
#  'do we have radio tech still monitor zone one radio tech radio shop air',
#  'ten four were',
#  'twenti two',
#  'seven two two go',
#  'i heard you say two r d thi will be north drake but we cant copi you',
#  'six two four',
#  'six two four',
#  'can i get six can i have an number',
#  'six two four we got cold',
#  'ticket plate light ten four',
#  'twelv',
#  'six twelv',
#  'six twelv we cant copi',
#  'your report number zero four eight six four zero fourti eight sixti four',
#  'youd tri come',
#  'sixteen two',
#  'sixteen two',
#  'im have problem tri run illinoi like veteran plate can you help me',
#  'can tri go it',
#  'i guess it disabl veteran plate it two seven six two seven six four um ida sam i believ ida sam begin',
#  'it illinoi though',
#  'yeah',
#  'okay stand by',
#  'seventeen twenti four you tri come',
#  'thi chicago polic dispatch point point radio correct time zero nine hundr hour twelfth august twenti eighteen station clear',
#  'radio test zone one two three four five six seven eight nine ten thi radio test zone one',
#  'radio shop test zone one one two three four five five four three two one radio shop test one two three four five',
#  'radio shop test one two three four five five four three two one how do you copi radio shop test one two three four five',
#  'fourti four hundr wonder if anybodi close fourti four hundr north menard thiri robert need one car no emerg',
#  'seventeen nine five robert',
#  'seventeen nine five robert',
#  'can you have avail sergeant take look my traffic crash report pleas',
#  'sergeant seventeen seventeen nineti five robert',
#  'sixteen thirti robert you okay yeah',
#  'thirti two robert head your way',
#  'alright thank',
#  'seven twelv',
#  'can we focu follow up miss fourti eight sixti north kruger',
#  'ten four sixteen eleven robert',
#  'eleven robert',
#  'check dui driver sixteen one hundr eliston theyr complain intox male hispan driver silver path finder got partial plate adam john had hi cellphon out',
#  'thirteen robert',
#  'seven thirteen robert',
#  'sixteen twenti three robert',
#  'six two three robert',
#  'we arriv',
#  'two six',
#  'sixteen one',
#  'six one',
#  'can you have thirti two robert call pleas',
#  'theyr an assist thirti right now but sixteen thirti two robert',
#  'alright they copi goodby',
#  'seven two two robert',
#  'two robert',
#  'good even you have person down montros cicero twenti year old male black pass out ground',
#  'by fire roll i have fourti seven rout just by costum shop',
#  'sixteen thirti two robert',
#  'sixteen thirti two robert',
#  'but im clear',
#  'alright',
#  'eleven robert nineteen fall show some station seem as',
#  'seven eleven robert alright',
#  'seven twenti three robert',
#  'three robert were back district were cycl here menard twenti four',
#  'okay ten four',
#  'so six two three robert just be clear from um person call help were just gonna like nineteen one',
#  'neg it wa unrel twenti four incid',
#  'i see he made transport so ten four',
#  'seven nine five robert',
#  'seventeen nine five rob',
#  'can you get traffic stop kedzi ainsli pleas',
#  'seventeen thirti two robert',
#  'seventeen thirti two robert call an assault progress lay bar three five six four belmont intox assault staff hey wear gray shirt jean',
#  'six twelv robert',
#  'six one two robert',
#  'six twelv robert unit um sixteen',
#  'call batteri progress eighti five twenti catalpa eighti five twenti west catalpa',
#  'caller say it sound like group peopl are fight',
#  'sound like it she say lot all noth further',
#  'sixteen fourteen robert you clear can you go over there twelv robert then just case',
#  'it your beat eighti five twenti cultap',
#  'fourteen robert you copi',
#  'ten four robert',
#  'alright twelv robert i guess um fourteen robert up now if you can take away if youd like or continu',
#  'seven eleven',
#  'seven eleven come',
#  'seven eleven robert two seven six five er correct seventi five per',
#  'okay ten four',
#  'sixteen thirti two robert',
#  'sixteen thirti two rob',
#  'i thought go jackson park locat other half thi mess chase peopl away',
#  'ten four jackson park blue line ten four two twenti three if you need it',
#  'elmwood park one',
#  'newli come',
#  'un one come reidentifi pleas',
#  'outsid agenc tri come zone one tri it again',
#  'six thirti two robert',
#  'thirti two robert go ahead',
#  'okay two twenti six',
#  'sixteen thirti robert',
#  'thirteen rob sixteen thirteen robert come',
#  'catalpa',
#  'seventeen thirti three robert',
#  'seventeen thirti three robert',
#  'one custodi five one can you pull an illinoi plate ticket',
#  'sure go ahead',
#  'averi union seven three nine six six',
#  'ten four',
#  'seventeen thirti three robert did you have jeep',
#  'pleas repeat',
#  'you had jeep',
#  'ten four',
#  'itll be bottom',
#  'seventeen twelv robert',
#  'seven twelv rob',
#  'what wa number followup mission',
#  'um one zero nine i got zero one nine five nine zero one nine five nine',
#  'seventeen twenti two robert',
#  'seven two two robert or two three',
#  'seventeen twenti two robert traffic stop fourti nine sixteen pulaski',
#  'seven two two robert ten four',
#  'seventeen thirti three robert go one',
#  'ten four thirti three two thirti if you need',
#  'seventeen twenti robert',
#  'seven twenti robert',
#  'give me vin number interact wilson drake',
#  'okay zero one one one seven zero one one one seven',
#  'thank you',
#  'seventeen twenti four robert',
#  'seventeen twenti four robert',
#  'station',
#  'okay ten four',
#  'thank you so',
#  'seven three one robert',
#  'seven thirti one robert',
#  'traffic stop',
#  'anderson cold air',
#  'sixteen thirti two',
#  'thirti eight twenti two ocanto neighbor play loud music hi own back',
#  'seventeen nineti seven',
#  'seven',
#  'yeah your guy from your accid belmont kimbal are call back',
#  'he want you come back there or mayb we can just call him',
#  'said other parti lie as who wa actual drive car',
#  'caus he say husband wa drive not wife he want you come back',
#  'nine nine ill call him',
#  'seventeen thirti three robert',
#  'thirti three robert',
#  'can we get our half an hour irv sawyer pleas',
#  'sure',
#  'sixteen twenti four robert',
#  'sixteen twenti four robert',
#  'batteri progress montros menard montros menard',
#  'four five fight street an offend ha red honda pilot scene',
#  'seventeen twenti three robert',
#  'seventeen twenti three robert',
#  'twenti three robert',
#  'fourti three hundr block bernard someon near one corner have parti music too loud',
#  'sixteen thirti four robert',
#  'thiri four robert',
#  'check out burglari report thirti five fourteen long apart 3 adam',
#  'regard burglari im go attempt thi uncommon spell name caller',
#  'ten four',
#  'sixteen twenti nineti seven',
#  'seventeen fifti call station pleas',
#  'seventeen fifti',
#  'will you call nineti seven station pleas',
#  'nineti nine',
#  'sixteen',
#  'sixteen twenti three robert',
#  'twenti three robert',
#  'got person call help by persh school fourti six fifti menard',
#  'amanda said she car hear lot yell outsid peopl are yell help she can hear peopl say get car not sure what go',
#  'teen thirteen robert',
#  'thirteen robert',
#  'im go go dow twenti two robert shift',
#  'okay',
#  'seven thirti two robert',
#  'seven',
#  'westbound addison from pulaski',
#  'behind male drive black jeep cheroke',
#  'alabama plate go west high rate speed blow light',
#  'sixteen twenti four robert',
#  'twenti four robert',
#  'can you put us down twenti three job can you middl school then',
#  'what you got over there',
#  'we got one person down ground',
#  'consciou breath',
#  'just hold him here',
#  'male or femal',
#  'male',
#  'school address good adresss becaus im now get anoth one',
#  'teen thirteen robert',
#  'thirteen robert',
#  'im menard eastwood i hear some scream',
#  'ahh ive got batteri progress wait now 4414 menard nine fight alley one down',
#  'adam william 12588',
#  'alright thirteen robert your look red nine honda four wheel drive selma gutierrez 613 north troy your next mark',
#  'alright six two four robert what good address your ambul',
#  'sixteen twenti four robert',
#  'one six two four robert',
#  'robert',
#  'what good address your ambul',
#  'sixteen twenti three robert',
#  'sixteen twenti three robert',
#  'can i have twenti four robert',
#  'sixteen twenti four robert mobil',
#  'teen twenti four',
#  'hey guy you wanna call me my cell phone',
#  'one six two four robert',
#  'twenti four robert',
#  'can we get an ambul over here male hispan look like he got lot blood him',
#  'i alreadi call them',
#  'sixteen thriti two robert',
#  'thirti two robert',
#  'assualt just occur thirti two hundr block central c mart secur guard threaten him',
#  'four',
#  'sixteen thirteen robert',
#  'sixteen thirteen ro',
#  'anybodi want from these from twenti four robert',
#  'i have no idea sixteen twenti three robert or sixteen twenti four robert',
#  'four rob',
#  'ani offend inform',
#  'we got were still tri figur out what go',
#  'thirteen robert would be neg no inform',
#  'what doe thirteen robert got',
#  'thirteen now one blood her theyr readi go',
#  'menard eastwood',
#  'yeah it probabl involv you can just bring him car bring him over here see if we could get thi figur out',
#  'ten four',
#  'sixteen thirteen radio check',
#  'sixteen thirteen maam good signal we just wanna check um my regular frequenc but i need you go back um citi wide five regular frequenc now thank you',
#  'fifteen radio check',
#  'seventeen eleven good signal thank you we just test radio zone um but i need you go back citi wide five our regular frequenc now thank you sir',
#  'one six three two radio check',
#  'six three two good signal can you do me favor count five',
#  'one two three four six five',
#  'thank you so much sir um i need you switch back citi wide five now',
#  'ten',
#  'one seven two three',
#  'one seven two three maam if you can also do radio check count five me',
#  'one two three four five',
#  'perfect thank you switch back citi wide five now',
#  'six six can we one radio check',
#  'copi you sir can you do me favor count five',
#  'absolut one two three four five',
#  'perfect thank you switch back now back citi wide five sir thank you',
#  'seventeen seventi two radio check zone one',
#  'great signal sir um can you count five four me',
#  'uno do tre cuatro cinco',
#  'thank you switch back um citi wide i mean zone back citi wide five now now im confus thank you sir',
#  'ten four',
#  'sixteen thirti three radio check',
#  'teen thirti three',
#  'radio check',
#  'come loud clear',
#  'seventeen twenti three radio check',
#  'twenti three',
#  'radio check',
#  'do i sound',
#  'good signal maam thank you',
#  'one six two one',
#  'one six two one',
#  'can i get my thirti minut fifti four hundr',
#  'ten four',
#  'teen thirti one',
#  'six thirti one',
#  'request our half hour pleas',
#  'sure what locat',
#  'nineti two eleven',
#  'nineti two eleven',
#  'can you have seventeen twenti two come station they have vehicl seven two three nine need car camera servic',
#  'seven two two you copi',
#  'ten four pull up',
#  'seventeen twelv',
#  'seventeen twelv',
#  'are we back over zone one',
#  'ten four',
#  'teen twelv',
#  'sixteen twelv',
#  'seventeen twelv',
#  'seventeen twelv',
#  'clear job',
#  'ten four',
#  'kedzi job alreadi torn area thi want person',
#  'ten four',
#  'four two',
#  'six fourti two',
#  'im clear from check nineteen paul can i get thirti minut normandi hay',
#  'ten four',
#  'one seven seven two',
#  'seventeen seventi two',
#  'there disturb montros cosner intox passeng bu number five three three one three he caus huge disturb bu face eastbound',
#  'sixteen twelv',
#  'six twelv',
#  'seven eleven',
#  'check wellb six two one one north lincoln mr hernandez said he been walk while he sound elderli look like he home depot walk while just case',
#  'yeah',
#  'seven two three back up',
#  'one seven two three',
#  'twenti three',
#  'did you have seven eleven check wellb six two one one north lincoln home depot mr hernadez he been walk while he didnt answer ani question he said he lost sound elderli',
#  'did complain',
#  'ten four',
#  'one six five two',
#  'sixteen fifti two',
#  'teen fifti two',
#  'one six five two meet fire depart element thirti nineth scene an auto accid',
#  'ten four',
#  'one six three four',
#  'six three four',
#  'ten four',
#  'sixteen sixti two eddi',
#  'sixteen sixti two eddi',
#  'comput interact elsa foster',
#  'els foster ten four',
#  'seventeen twelv',
#  'if you could put last disturb',
#  'residenti panic alarm we out car said thirti',
#  'two six north carlyl',
#  'said two six north carlyl',
#  'panic alarm by veron roja',
#  'it wa activad from insid backyard thi locat',
#  'four',
#  'sixteen thirti three',
#  'six three three',
#  'we have thirti nine belmont menard',
#  'belmont menard ten four',
#  'two eleven',
#  'seven eleven',
#  'contact drive home',
#  'when mayb',
#  'we will tri it',
#  'he insid possibl home depot',
#  'ill check insid home depot',
#  'one six three two',
#  'sixteen sixti two',
#  'sixteen thirti two are we suppos be zone one or are we suppos be citi wide five',
#  'sixteen thirti two we back zone',
#  'k do you have me do radio check then',
#  'when id did they told me tri zone five so',
#  'radioshop zone one radio check one two three four five five four three two one',
#  'radioshop test',
#  'zone one',
#  'one two three four five',
#  'five four three two one',
#  'okay i hear you loud clear how did i know',
#  'sound good',
#  'okay one two three four five five four three two one radio shop test',
#  'squad sixteen seventeen back zone',
#  'sixteen sixteen your charli',
#  'zone citi wide five b five',
#  'sixteen sixti two charli',
#  'zone one posit b five citi wide five be advis',
#  'seventeen twenti two robert',
#  'seventeen twenti two robert',
#  'yeah go over fourti three six pulaski apart d two second floor',
#  'assist fifti eight thirti three',
#  'pictur from an earlier domest batteri i guess offend back scene',
#  'four',
#  'seventeen twenti four robert',
#  'seven two four robert',
#  'can we get mission beach',
#  'seventeen fourti one robert',
#  'fourti one robert',
#  'can you draw us twenti two robert',
#  'seventeen nineti five robert',
#  'ten rob',
#  'auto accid now montros christiana',
#  'two car unsur injuri',
#  'seventeen eleven',
#  'eleven',
#  'did alex show up yet',
#  'yeah alex show up twenti',
#  'twenti three ten hour were just secur apart right now',
#  'okay i no i just need know what time they show up thank',
#  'fifteen fifti three',
#  'five three',
#  'hi grab some lunch california',
#  'okay',
#  'seventeen twenti three robert',
#  'seventeen twelv robert',
#  'seven twelv robert',
#  'yeah take ride fire fifti three fourti two kedzi apart ten second floor',
#  'thirti one year old male unrespons',
#  'girlfriend claim it onli caus he broke hi foot but fire think there someth more it they want us join em',
#  'ten four',
#  'teen thirti three robert',
#  'thirti three robert',
#  'can you hold us down station do an ethic train',
#  'teen one',
#  'one',
#  'twenti three robert you got over hospit',
#  'yeah theyv been here there sinc befor ha',
#  'you have them give me call vess real quick',
#  'alright seventeen twenti three robert',
#  'one seven two three robert',
#  'seven',
#  'will you call seventeen one pleas also let me know what you actual have over there so i can do my notif',
#  '',
#  'sixteen fourteen robert',
#  'come an assist blue line cumberland medina cimberland',
#  'alan burton say park drive gate wont come up or let them pay their money',
#  'bunch car are stuck there',
#  'um',
#  'tell them break gate themselv i dont know or call cta',
#  '',
#  '',
#  'twelv robert',
#  'yeah he refus em he broke hi leg coupl day ago',
#  'okay',
#  'seven five one',
#  'five one',
#  '',
#  'alright',
#  'seventeen nine five robert',
#  'nineti five robert',
#  'callback',
#  'thi come from third parti caller he w he just good citizen',
#  'teen thirti five robert',
#  'nineti five robert',
#  'then third parti caller',
#  'ye',
#  '',
#  'seventeen er sixteen twenti three rob',
#  'teen twenti three robert',
#  'yeah domest fifti eight twenti nine lawrenc apart number two second floor',
#  'name morri problem drunk sister',
#  'um',
#  'te polic were there earlier today some',
#  '',
#  'ten four',
#  'okay',
#  'okay it not what i thought it wa',
#  'teen nineti five robert',
#  'nineti five robert',
#  'can you put us traffic mission irv park belmont',
#  'it right over river',
#  'seventeen eleven robert',
#  'eleven robert',
#  'get nineteen fall',
#  'head fourti three job',
#  '',
#  'traffic crash irv',
#  'six twenti three robert',
#  'six twenti three robert',
#  'your travel fifti two twenti nine charl complain about toyota highland park by hydrant',
#  'not hold you park',
#  'ten four',
#  'seven five',
#  'five',
#  'clear from',
#  '',
#  'launch foster pla',
#  '',
#  'six twenti two',
#  'twenti two',
#  'nineteen call zebra fourti seven took him over commun first ill follow him there',
#  'big thank everybodi show up',
#  'six two three robert',
#  'twenti three robert',
#  'check male over wheel montros lavern',
#  'male black jeep wrangler sleep wheel face westbound',
#  'sixti thirti three rob',
#  'thirti three robert',
#  'come as an assault progress irv central but address portag park ivan say',
#  'two drunk femal versu him',
#  'two femal one an red shirt one',
#  'hat short anoth one black shirt short',
#  'four',
#  'sixteen nineti six robert',
#  'nineti six robert',
#  'ga o',
#  'sure',
#  'sixti thirti four robert',
#  'one six three four robert',
#  'six three four robert',
#  'fifti one fourti one bernic see ms martinez',
#  'she complain about femal outsid her apart argu',
#  'thirti two wa there earlier becaus femal thought her daughter wa there',
#  'femal hispan just sit her black gray suv',
#  'ten four',
#  'twenti three robert',
#  '',
#  'wheel',
#  'one seven six one charli',
#  'charli',
#  'traffic stop four two five three north kimbal',
#  'sixteen twenti four robert',
#  'four robert',
#  'residenti alarm fourti five eighti five narragansett roger tolo resid back patio mo',
#  'seventeen fifti',
#  'one seven five three',
#  'seventeen fifti three',
#  'fourti four thirti hamlock loud parti yell come from alley backyard',
#  'ten four',
#  'seven zero robert',
#  'thirti one robert',
#  'control park',
#  'one seven five one',
#  'five one',
#  'make two boy',
#  'log us off thi comput we have switch car',
#  'okay',
#  'seventeen eleven robert',
#  'seventeen eleven robert',
#  'yeah sixti three thirti four hamlin jame said there male stand',
#  'talk loud laugh curs',
#  'never had thi befor dont know where these guy came from',
#  'ten four',
#  'thirti two',
#  'thirti two come',
#  'commun first',
#  'bernic',
#  'let me know if thi gonna be bona fide or not',
#  'could anybodi sixteen can clear up take commerci alarm been wait',
#  'teen thirti three robert',
#  'sixteen thirti three robert',
#  'give you photo',
#  '',
#  'sixteen twenti two',
#  'yeah sixti two twenti one lacross',
#  'group teen street are drunk adn drink beer',
#  'four',
#  'sixteen twenti',
#  'there sixteen twenti out there tonight',
#  'there not',
#  'thank you sixteen thirti robert',
#  'thirti robert',
#  'got request supervisor you fifti fourti eight dakin',
#  'thirti four domest sister call she want brother remov claim they wont remov him',
#  'alright ill over',
#  '',
#  'thirti two',
#  'set up camera go into commun',
#  'okay',
#  'seventeen thirti three robert',
#  'seven thirti three robert',
#  'yeah caller call back from rosco california said person',
#  'wa look window got into white hatchback plate',
#  'georg union six five nine four six',
#  'then went east rosco toward california',
#  'ten four',
#  'sixteen thirti one robert',
#  'thirti one robert',
#  'thriti sev',
#  'need',
#  'anoth offic there',
#  'alright',
#  'seventeen thirti one robert',
#  'seven three one robert',
#  'come domest fourti two sixti five addison',
#  'someon bang window scream no descript',
#  'no call back',
#  'seventeen thirti two our',
#  'when did you get call',
#  'it just pope up now',
#  'yeah our we got get our lock down we got out our car were take thi blue line disregard now',
#  'seven thirti one robert disregard it',
#  'copi thank you',
#  'seventeen fifti five',
#  'seven five five',
#  'check auto accid kedzi irv fire roll',
#  'seven four three robert',
#  'fourti three robert',
#  'put us scene also',
#  'accid',
#  '',
#  'seven three robert',
#  'fourti three robert',
#  'can we get an ambul roll thi way',
#  'femal hispan head injuri',
#  'fire alreadi roll',
#  'you write up then thank you',
#  '',
#  'one seven four three',
#  'fourti three',
#  'ofic',
#  'seven ten three robert',
#  'fourti three robert',
#  'can we get anoth unit over here redirect traffic west bound traffic flow',
#  'or from kedzi go west we need redirect caus there three car middl lane',
#  'alright fifti five rout over there',
#  'one seven five four traffic stop thirti six fourti one west',
#  'k',
#  'six six one boy',
#  'one boy were get ga what go',
#  'thi relat suspici auto i gave you just info just take look it',
#  'we just look there squad there wa no one out nineteen boy but well take an',
#  'alright',
#  'teen sixti one eddi',
#  'eddi',
#  'number commun confirm',
#  'fourti nine fourti five west baron',
#  'seventeen fifti three',
#  '',
#  'take thi check well be fourti four fourti five pulaski insid littl cesar you got michael call',
#  'regard femal hispan approxim ten year old',
#  'wear gray emoji shirt cri appear be male hispan black shirt red shirt she doesnt seem know him',
#  'caller ask litl girl if she wa okay if she knew male',
#  'all she did wa look down didnt say male whisper someth her',
#  'i think you should check her',
#  'ten four',
#  'seventeen fourti one',
#  'im sorri seven fourti one robert',
#  'fourti one robert',
#  'batteri progress lawrenc kildair lawrenc kildair male fight femal one corner',
#  'ten four',
#  'seventeen eleven',
#  'eleven',
#  'yeah',
#  'hour',
#  'okay',
#  'teen sixti one david',
#  'david',
#  '',
#  'wanna tri again sinc some goof wa be two year old',
#  'my idiot partner next me do',
#  'you got ani concern addison school',
#  'okay',
#  'doesnt supris me he wa do it',
#  'supris me',
#  'childish',
#  'just littl bit',
#  'seventeen seventi two',
#  'go station i got one go sixteen',
#  'seventeen fourti one robert',
#  'fourti one robert',
#  'nineteen job can you put us robberi i didnt get event number pleas',
#  'you got number',
#  'sixteen elven robert',
#  'eleven robert',
#  'anyth job odel from an hour ago',
#  'cordel',
#  'seventeen thirteen robert',
#  'thirteen robert',
#  'clear from show us sunni side',
#  'okay',
#  'six five',
#  'five',
#  'yeah we got',
#  'stop schopin park',
#  'got multi name i',
#  'run it see if it valid warrant',
#  'warrant all',
#  'run',
#  'okay what name',
#  'alright last name gonna be two word aguileramaldonado',
#  'adam',
#  'georg union',
#  'ida lincoln eddi robert adam',
#  'mari adam lincoln david ocean nora adam david',
#  'know when your readi rest',
#  'alright give me first name',
#  'two first name first one go be mario common spell mari',
#  'adam robert ida ocean',
#  'then ricardo',
#  'robert ida charli adam robert david ocean',
#  'got birthday',
#  'three april seventi nine',
#  'driver',
#  'sixteen eleven robert',
#  '',
#  'suspic auto occup seven five three eight north odel',
#  'seventi five thirti eight north odel avenu femal ha been sit insid burgandi two door car',
#  'least three hour front locat noth further after just park be',
#  'sixteen thirteen robert',
#  'teen thirteen robert',
#  'good even disturb five two two zero north harlem',
#  'fifti two twenti north harlem baker squar john call',
#  'he said caller wa restuar when some worker were smoke back restur',
#  'blew marijuana smoke hi face em refus noth further',
#  'ten four',
#  'sixteen twenti two',
#  'sixteen twenti two one six two two',
#  'sixteen',
#  'help me out disturb mental pleas four eight eight four north mason',
#  'fourti eight eighti four north mason avenu don caller son act strang agress',
#  'joshua thirti year old black short',
#  'doe exist',
#  'he bipolar schizophren',
#  'he violent unsur medic noth further',
#  'four',
#  'teen thirteen robert',
#  'one seven one three robert',
#  'station report pleas',
#  'ten four',
#  'sixteen twenti three robert',
#  'good even maam when your up roll disturb five six one seven west',
#  'fifti six seventeen west column avenu coupl call here',
#  'pizza restur call intox femal white sit black nissan yell custom employe',
#  'licens xray eight one six eight seven seven',
#  'second call say waitress accus caller be belliger drunk',
#  'she by super',
#  'didnt provid an exact address',
#  'noth further',
#  'seventeen eleven robert',
#  'seventeen eleven robert one seven one one robert',
#  '',
#  'good even sir when your up roll auto accid kimbal hollywood hollywood kimbal',
#  'van dilda who call',
#  'got coupl call here um',
#  'hit run silver kia optima',
#  'wa hit by car while it wa park noth further',
#  'ten four',
#  'ten four',
#  'seventeen twenti three robert',
#  'teen twenti three robert',
#  'take crimin sexual assualt report seventeen pleas',
#  'femal hospit',
#  'report she afraid talk about it noth further',
#  ...]
